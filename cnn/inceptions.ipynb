# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.223 🚀 Python-3.12.11 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 5090, 32101MiB)
# Setup complete ✅ (32 CPUs, 125.5 GB RAM, 266.7/1831.7 GB disk)

# %%
import torch
import torch.nn.functional as F

# %%
def dice(pred,target,smooth=1e-6):
    intersection=(pred*target).sum()
    union=pred.sum()+target.sum()
    return 1-(2.*intersection+smooth)/(union+smooth)

# %%
pred=torch.tensor([0.9,0.1,0.8,0.3])
target=torch.tensor([1.,0.,1.,0.])

## Cross entropy loss
ce_loss=F.binary_cross_entropy(pred,target)
dice_loss=dice(pred,target)

# %%
def segmentation_loss(ce_loss,dice_loss,weightage=0.5):
    return ce_loss*weightage+dice_loss

# %%
segmentation_loss(ce_loss,dice_loss)
# Out:
# tensor(0.2695)

# %% [markdown]
# ### Fully Convolution Network (FCNs)
